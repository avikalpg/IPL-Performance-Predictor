# %%
import requests
import sys

# %%
# url = "https://rest.cricketapi.com/rest/v3/players_list/"
# params = {
#     "access_token":"",
#     "board":"icc",
#     "competition":"international-t20",
#     "year":"2018"
# }
# r = requests.get(url, params=params)

# %%
url = "https://cricketapi.platform.iplt20.com/stats/players"
querystring = {"teamIds":"1","tournamentIds":"7749","scope":"TOURNAMENT","pageSize":"30"}
headers = {
    'origin': "https://www.iplt20.com",
    'account': "ipl",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36",
    'content-type': "application/x-www-form-urlencoded; charset=UTF-8",
    'accept': "*/*",
    'referer': "https://www.iplt20.com/teams/delhi-daredevils/squad",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "en-US,en;q=0.9",
    'cache-control': "no-cache",
    }
response = requests.request("GET", url, params=querystring)
print(response.text)
# Out:
# {"tournament":{"id":7749,"name":"ipl2018","description":"IPL 2018","provisional":false,"startDate":"2018-04-07T20:00:00+0530","endDate":"2018-05-27T23:00:00+0530","matchesByType":{"IPLT20":60}},"team":{"id":1,"fullName":"Chennai Super Kings","shortName":"Super Kings","abbreviation":"CSK","type":"m","primaryColor":"FDB913","secondaryColor":"0081E5"},"stats":{"pageInfo":{"page":0,"numPages":1,"pageSize":30,"numEntries":26},"content":[{"player":{"id":1,"fullName":"MS Dhoni","shortName":"MS Dhoni","nationality":"Indian","dateOfBirth":"1981-07-07","rightArmedBowl":true,"rightHandedBat":true},"stats":[{"matchType":"T20","battingStats":{"50s":1,"100s":0,"inns":5,"m":5,"r":"139","b":92,"4s":11,"6s":7,"no":2,"hs":"79*","sr":"151.08","a":"46.33"},"bowlingStats":{"bbiw":0,"bbir":0,"bbmw":0,"bbmr":0,"4w":0,"5w":0,"10w":0,"inns":0,"m":5,"b":0,"r":0,"wb":0,"nb":0,"d":0,"w":0,"4s":0,"6s":0,"maid":0,"wmaid":0,"ht":0,"a":"-","e":"-","sr":"-","o":"-"},"fieldingStats":{"c":5,"ro":0,"s":0,"inns":3,"m":5
# ...

# %%
print(r)
r.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e83055fa21cd> in <module>()
# ----> 1 print(r)
#       2 r.content
#
# NameError: name 'r' is not defined
