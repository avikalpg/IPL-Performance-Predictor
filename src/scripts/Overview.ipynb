# %%
import sys
sys.path.append("../lib")
import Utilities as utl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

# %%
venue = "Wankhede Stadium"
team_1 = "Mumbai Indians"
team_2 = "Sunrisers Hyderabad"

# %%
player_df = pd.read_csv("../../ipl-data-till-2017/Player.csv",encoding = "ISO-8859-1")
bbb_df = pd.read_csv("../../ipl-data-till-2017/Ball_By_Ball.csv",encoding = "ISO-8859-1")
match_df = pd.read_csv("../../ipl-data-till-2017/Match.csv",encoding = "ISO-8859-1")
pm_df = pd.read_csv("../../ipl-data-till-2017/Player_match.csv",encoding = "ISO-8859-1")
team_df = pd.read_csv("../../ipl-data-till-2017/Team.csv",encoding = "ISO-8859-1")

# %%
# player_df
# team_df
match_df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
todays_match = match_df[(match_df.Venue_Name == venue) & (match_df.Team1 == team_1) & (match_df.Team2 == team_2)]

# %%
print(len(todays_match))
todays_match.groupby(["Season_Year", "match_winner"]).size()
# Out:
# 3
# Season_Year  match_winner
# 2013         Mumbai Indians    1
# 2015         Mumbai Indians    1
# 2017         Mumbai Indians    1
# dtype: int64

# %%
pm_df.columns
# pm_df[(pm_df.Venue_Name == venue) & (pm_df.Team1 == team_1) & (pm_df.Team2 == team_2)]
# Out:
# Index(['Player_match_SK', 'PlayerMatch_key', 'Match_Id', 'Player_Id',
#        'Player_Name', 'DOB', 'Batting_hand', 'Bowling_skill', 'Country_Name',
#        'Role_Desc', 'Player_team', 'Opposit_Team', 'Season_year',
#        'is_manofThematch', 'Age_As_on_match', 'IsPlayers_Team_won',
#        'Batting_Status', 'Bowling_Status', 'Player_Captain', 'Opposit_captain',
#        'Player_keeper', 'Opposit_keeper'],
#       dtype='object')

# %%
todays_pm = pm_df[(pm_df.Player_team == team_1) | (pm_df.Player_team == team_2)]

# %%
todays_pm.groupby(["Player_Name"]).agg('first')
# Out:
#                       Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# Player_Name
# A Ashish Reddy                  19830     5.980050e+10    598005        325
# A Mishra                        19828     5.980050e+10    598005        136
# A Nehra                         12769     3.359900e+10    335990         73
# A Nel                           13793     3.360370e+10    336037        438
# A Symonds                       16809     5.012150e+10    501215         56
# AC Blizzard                     17478     5.012460e+10    501246        289
# AG Murtaza                      15256     4.191120e+10    419112        286
# AJ Finch                        21523     7.292900e+10    729290        254
# AM Nayar                        12765     3.359900e+10    335990         48
# AM Rahane                       12978     3.359990e+10    335999         85
# AN Ahmed                        16026     4.191470e+10    419147        246
# ...

# %%
squad_team_1 = utl.getSquad(utl.getBaseName(team_1))
squad_team_2 = utl.getSquad(utl.getBaseName(team_2))

# %%
player_names = []
for player in squad_team_1:
    player_names.append(player["player"]["fullName"])
#     player_names.append(player["player"]["shortName"])
player_namesplayer_names = []
for player in squad_team_1:
    player_names.append(player["player"]["fullName"])
#     player_names.append(player["player"]["shortName"])
player_names
# Out:
# ['Akila Dananjaya',
#  'Tajinder Singh',
#  'Ben Cutting',
#  'Sharad Lumba',
#  'Kieron Pollard',
#  'Mayank Markande',
#  'Mohsin Khan',
#  'Mitchell McClenaghan',
#  'Pradeep Sangwan',
#  'MD Nidheesh',
#  'Ishan Kishan',
#  'Aditya Tare',
#  'Saurabh Tiwary',
#  'Jasprit Bumrah',
#  'Evin Lewis',
#  'Rohit Sharma',
#  'Suryakumar Yadav',
#  'Krunal Pandya',
#  'Adam Milne',
#  'Rahul Chahar',
#  'Siddhesh Lad',
#  'Hardik Pandya',
#  'JP Duminy',
#  'Mustafizur Rahman',
#  'Anukul Roy']

# %%
player_names = []
for player in squad_team_1:
#     player_names.append(player["player"]["fullName"])
    player_names.append(player["player"]["shortName"][0] + " "+ player["player"]["shortName"].split(" ")[-1])
player_names
# Out:
# ['A Dananjaya',
#  'T Singh',
#  'B Cutting',
#  'S Lumba',
#  'K Pollard',
#  'M Markande',
#  'M Khan',
#  'M McClenaghan',
#  'P Sangwan',
#  'M Nidheesh',
#  'I Kishan',
#  'A Tare',
#  'S Tiwary',
#  'J Bumrah',
#  'E Lewis',
#  'R Sharma',
#  'S Yadav',
#  'K Pandya',
#  'A Milne',
#  'R Chahar',
#  'S Lad',
#  'H Pandya',
#  'J Duminy',
#  'M Rahman',
#  'A Roy']

# %%
pm_df[pm_df.Player_Name.fillna('').apply(lambda x: ('' if (x == '') else (x[0] + " " + x.split(" ")[-1])) in player_names)].groupby(["Player_Name"]).agg('first')
# Out:
#                    Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# Player_Name
# AF Milne                     24144     9.809120e+10    980912        461
# AP Tare                      15252     4.191120e+10    419112        207
# BCJ Cutting                  22351     7.340160e+10    734016        385
# HH Pandya                    23142     8.297420e+10    829742        400
# Ishan Kishan                 24122     9.809100e+10    980910        410
# JJ Bumrah                    19821     5.980040e+10    598004        375
# JP Duminy                    13990     3.921860e+10    392186        154
# KA Pollard                   15410     4.191190e+10    419119        221
# KH Pandya                    24265     9.809220e+10    980922        413
# MJ McClenaghan               23143     8.297420e+10    829742        403
# Mustafizur Rahman            24155     9.809120e+10    980912        460
# PJ Sangwan                   13120     3.360060e+10    336006        116
# ...

# %%
print(len(player_names))
pm_df[pm_df.Player_Name.fillna('').apply(lambda x:  in x)].groupby(["Player_Name"]).agg('first')
# Out:
# 25
#                    Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# Player_Name
# Ishan Kishan                 24122     9.809100e+10    980910        410
# JP Duminy                    13990     3.921860e+10    392186        154
# Mustafizur Rahman            24155     9.809120e+10    980912        460
#
#                          DOB   Batting_hand         Bowling_skill  \
# Player_Name
# Ishan Kishan       7/18/1998  Left-hand bat                   NaN
# JP Duminy          4/14/1984  Left-hand bat    Right-arm offbreak
# Mustafizur Rahman   9/6/1995  Left-hand bat  Left-arm fast-medium
#
#                    Country_Name Role_Desc          Player_team      ...        \
# Player_Name                                                         ...
# Ishan Kishan              India    Player        Gujarat Lions      ...
# JP Duminy          South Africa    Player       Mumbai Indians      ...
# Mustafizur Rahman    Bangladesh    Player  Sunrisers Hyderabad      ...
#
# ...
