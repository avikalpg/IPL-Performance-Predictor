# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

# %%
player_df = pd.read_csv("../ipl-data-till-2017/Player.csv",encoding = "ISO-8859-1")
bbb_df = pd.read_csv("../ipl-data-till-2017/Ball_By_Ball.csv",encoding = "ISO-8859-1")
match_df = pd.read_csv("../ipl-data-till-2017/Match.csv",encoding = "ISO-8859-1")
pm_df = pd.read_csv("../ipl-data-till-2017/Player_match.csv",encoding = "ISO-8859-1")
team_df = pd.read_csv("../ipl-data-till-2017/Team.csv",encoding = "ISO-8859-1")

# %%
# player_df
# team_df
match_df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
todays_match = match_df[(match_df.Venue_Name == "Feroz Shah Kotla") & (match_df.Team1 == "Delhi Daredevils") & (match_df.Team2 == "Kings XI Punjab")]

# %%
print(len(todays_match))
todays_match.groupby(["Season_Year", "match_winner"]).size()
# Out:
# 9
# Season_Year  match_winner
# 2008         Kings XI Punjab     1
# 2010         Kings XI Punjab     1
# 2011         Delhi Daredevils    1
# 2012         Delhi Daredevils    1
# 2013         Kings XI Punjab     1
# 2014         Kings XI Punjab     1
# 2015         Delhi Daredevils    1
# 2016         Delhi Daredevils    1
# 2017         Delhi Daredevils    1
# dtype: int64

# %%
pm_df.columns
# pm_df[(pm_df.Venue_Name == "Feroz Shah Kotla") & (pm_df.Team1 == "Delhi Daredevils") & (pm_df.Team2 == "Kings XI Punjab")]
# Out:
# Index(['Player_match_SK', 'PlayerMatch_key', 'Match_Id', 'Player_Id',
#        'Player_Name', 'DOB', 'Batting_hand', 'Bowling_skill', 'Country_Name',
#        'Role_Desc', 'Player_team', 'Opposit_Team', 'Season_year',
#        'is_manofThematch', 'Age_As_on_match', 'IsPlayers_Team_won',
#        'Batting_Status', 'Bowling_Status', 'Player_Captain', 'Opposit_captain',
#        'Player_keeper', 'Opposit_keeper'],
#       dtype='object')

# %%
todays_pm = pm_df[(pm_df.Player_team == "Delhi Daredevils") | (pm_df.Player_team == "Kings XI Punjab")]

# %%
todays_pm.groupby(["Player_Name"]).agg('first')
# Out:
#                  Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# Player_Name
# A Mishra                   13430     3.360200e+10    336020        136
# A Nehra                    14126     3.921940e+10    392194         73
# AB Agarkar                 17087     5.012280e+10    501228         82
# AB Barath                  15485     4.191220e+10    419122        227
# AB Dinda                   16624     5.012060e+10    501206        106
# AB McDonald                15056     3.922370e+10    392237        198
# AB de Villiers             13119     3.360060e+10    336006        110
# AC Gilchrist               16634     5.012070e+10    501207         53
# AD Mascarenhas             18309     5.483180e+10    548318        137
# AD Mathews                 22884     8.297200e+10    829720        191
# AD Russell                 18666     5.483340e+10    548334        334
# AJ Finch                   16630     5.012060e+10    501206        254
# ...
